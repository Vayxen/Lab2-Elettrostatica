# %%
 #generatore a 30V sul condensatore, d = 7mm
#misurare Velettrometro attaccato al condensatore

import numpy as np


eps0 = 8.859E-12

Dc = 0.18
Dcerr = 0.0001
Dc = Dc-np.random.normal(0, Dcerr, 1)
#Dc = 

Ac = np.pi/4*Dc**2
Ac_err = Ac*2*Dcerr/Dc

d = 0.007
derr = 0.0005
d = d-np.random.normal(0, derr, 1)
#d=

Cc = eps0*Ac/d
Ccerr = Cc*((derr/d)**2+(Ac_err/Ac)**2)**(1/2)

V = 30
Verr = 0#V/100*5
#commentare
V = V-np.random.normal(0, Verr, 1)

Ve = Cc*V/(100*10**(-12)+Cc)
print(Ve)
Ve_err = 0.3
#commentare
#Ve = Ve-np.random.normal(0, Ve_err, 1)
Ve = 3.7
Ce = Cc*(V-Ve)/Ve
VmenoVe_eps = ((Ve_err/Ve)**2+(Verr/V)**2)**(1/2)
#Ce_err = Ce*((Ccerr/Cc)**2+(VmenoVe_eps+Ve_err/Ve)**2)**(1/2)
Ce_err = (((V-Ve)/Ve*Ccerr)**2+(Cc/Ve*Verr)**2+(Cc*V/Ve**2*Ve_err)**2)**(1/2)

print("Ce, Ce_err")
print(Ce)
print(Ce_err)
# Out:
# [7.00244843]
# Ce, Ce_err
# [2.16432433e-10]
# [2.4794788e-11]

# %%
#generatore a 30V sul condensatore, d = 7mm
#misurare Velettrometro attaccato al condensatore

import numpy as np


eps0 = 8.859E-12

Dc = 0.18
Dcerr = 0.0001
Dc = Dc-np.random.normal(0, Dcerr, 1)
#Dc = 

Ac = np.pi/4*Dc**2
Ac_err = Ac*2*Dcerr/Dc

d = 0.003
derr = 0.0005
d = d-np.random.normal(0, derr, 1)
#d=

Cc = eps0*Ac/d
Ccerr = Cc*((derr/d)**2+(Ac_err/Ac)**2)**(1/2)

V = 30
Verr = 0#V/100*5
#commentare
V = V-np.random.normal(0, Verr, 1)

Ve = Cc*V/(100*10**(-12)+Cc)
print(Ve)
Ve_err = 0.3
#commentare
#Ve = Ve-np.random.normal(0, Ve_err, 1)
Ve = 12
Ce = Cc*(V-Ve)/Ve
VmenoVe_eps = ((Ve_err/Ve)**2+(Verr/V)**2)**(1/2)
#Ce_err = Ce*((Ccerr/Cc)**2+(VmenoVe_eps+Ve_err/Ve)**2)**(1/2)
Ce_err = (((V-Ve)/Ve*Ccerr)**2+(Cc/Ve*Verr)**2+(Cc*V/Ve**2*Ve_err)**2)**(1/2)

print("Ce, Ce_err")
print(Ce)
print(Ce_err)
# Out:
# [11.4741229]
# Ce, Ce_err
# [9.2903479e-11]
# [1.33526036e-11]
